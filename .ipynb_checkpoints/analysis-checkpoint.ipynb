# %%
from sp_analysis import load_data, KPI_LABELS, prepare_by_kpi_all_countries, facet_chart_by_country


#sheet_id = '1m9Phl1uxPN9hL4zmgSGFMOFs1X-UmjxP'
#gid = '663340094'
#url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&gid={gid}'


df = load_data()
ALL_KPIS = list(KPI_LABELS.keys())
long_df = prepare_by_kpi_all_countries(df, ALL_KPIS)

facet_chart_by_country(long_df, country='Austria', title='Austria — All KPIs')
# Out:
# alt.FacetChart(...)

# %%
from sp_analysis import load_data, KPI_LABELS, prepare_by_kpi_all_countries, facet_chart_by_country

sheet_id = '1m9Phl1uxPN9hL4zmgSGFMOFs1X-UmjxP'
gid = '663340094'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&gid={gid}'
df = load_data(url)

df.to_csv('data/sp_data.csv', index=False)
# Out:
#     ISO2     countryname      SP  year  c1_visits  c2_user  c3_pdoDeliver  \
# 0     AT         Austria  AUSSDA  2020    14248.0    938.0         6335.0
# 1     AT         Austria  AUSSDA  2021    16688.0    829.0         7954.0
# 2     AT         Austria  AUSSDA  2022     9211.0    926.0         8294.0
# 3     AT         Austria  AUSSDA  2023     9854.0   4481.0         7831.0
# 4     AT         Austria  AUSSDA  2024    15416.0   5367.0        14467.0
# ..   ...             ...     ...   ...        ...      ...            ...
# 131   UK  United Kingdom    UKDS  2021  1059931.0  47167.0       215979.0
# 132   UK  United Kingdom    UKDS  2022   873844.0  47998.0       212546.0
# 133   UK  United Kingdom    UKDS  2023  2951843.0  48471.0       236900.0
# 134   UK  United Kingdom    UKDS  2024  3199045.0  52236.0       205910.0
# 135   UK  United Kingdom    UKDS  2025   834639.0  54687.0       164605.0
#
#      c3_pdoDeliver_pid  c4_events  c6_eAttendees  ... c10_pdoStored  \
# 0               6335.0        NaN            NaN  ...         741.0
# 1               7954.0        3.0           47.0  ...        1166.0
# 2               8294.0        8.0           50.0  ...        1400.0
# 3               7831.0        6.0           62.0  ...        1527.0
# 4              14467.0        9.0          205.0  ...        1567.0
# ..                 ...        ...            ...  ...           ...
# 131           215979.0       93.0         5029.0  ...        8530.0
# 132           212546.0      116.0         6977.0  ...        9021.0
# 133           236900.0      153.0         5620.0  ...        9298.0
# 134           205910.0      176.0         4224.0  ...        9700.0
# 135           164605.0      109.0         4459.0  ...       12049.0
#
#      c10_pdoStored_pid c13_staff  c14_nfunds  c15_cstaff  c16_cfunds  \
# 0                741.0     11.00    500000.0        1.00    500000.0
# 1               1166.0     11.00    500000.0        1.00         NaN
# 2               1400.0     12.00    912654.0        2.00         NaN
# 3               1527.0     12.00    960000.0        1.00         NaN
# 4               1567.0     12.50   1000000.0        2.00         NaN
# ..                 ...       ...         ...         ...         ...
# 131             8530.0     62.20   4409108.0        2.66     75932.0
# 132             9021.0     69.95   5185091.0        2.80    148707.0
# 133             9298.0     75.30   7278987.0        2.80    157630.0
# 134             9700.0     65.70   7043475.0        2.60    167403.0
# 135            12049.0     65.50   7636453.0        2.00    171586.0
#
#           c18_trl8  c18_trl6   c19_pub   c19a_peer
# 0           01--03       NaN       NaN         NaN
# 1           01--03       NaN     133.0         NaN
# 2           01--03       NaN     199.0         NaN
# 3           01--03    00--02     269.0     60--79%
# 4           01--03    00--02     303.0     60--79%
# ..             ...       ...       ...         ...
# 131  Not evaluated       NaN  572188.0         NaN
# 132  Not evaluated       NaN  646308.0         NaN
# 133           >=10      >=13  515928.0  Don't know
# 134           >=10      >=13  584146.0  Don't know
# 135           >=10      >=13  810652.0  Don't know
#
# [136 rows x 23 columns]
